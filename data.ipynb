# %%
import cv2

# %%
import cv2
import os

output_dir = "dataset2"
os.makedirs(output_dir, exist_ok=True)

cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

num_photos = 100
for i in range(num_photos):
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    img_name = os.path.join(output_dir, f"photo_{i+1}.jpg")
    cv2.imwrite(img_name, frame)
    print(f"Saved {img_name}")

    cv2.imshow("Capturing Photos", frame)

    if cv2.waitKey(100) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
print(f"Captured and saved {i+1} photos in '{output_dir}' directory.")
# Out:
# Saved dataset2\photo_1.jpg
# Saved dataset2\photo_2.jpg
# Saved dataset2\photo_3.jpg
# Saved dataset2\photo_4.jpg
# Saved dataset2\photo_5.jpg
# Saved dataset2\photo_6.jpg
# Saved dataset2\photo_7.jpg
# Saved dataset2\photo_8.jpg
# Saved dataset2\photo_9.jpg
# Saved dataset2\photo_10.jpg
# Saved dataset2\photo_11.jpg
# Saved dataset2\photo_12.jpg
# Saved dataset2\photo_13.jpg
# Saved dataset2\photo_14.jpg
# Saved dataset2\photo_15.jpg
# Saved dataset2\photo_16.jpg
# Saved dataset2\photo_17.jpg
# Saved dataset2\photo_18.jpg
# Saved dataset2\photo_19.jpg
# Saved dataset2\photo_20.jpg
# Saved dataset2\photo_21.jpg
# Saved dataset2\photo_22.jpg
# Saved dataset2\photo_23.jpg
# Saved dataset2\photo_24.jpg
# Saved dataset2\photo_25.jpg
# Saved dataset2\photo_26.jpg
# Saved dataset2\photo_27.jpg
# Saved dataset2\photo_28.jpg
# Saved dataset2\photo_29.jpg
# Saved dataset2\photo_30.jpg
# Saved dataset2\photo_31.jpg
# Saved dataset2\photo_32.jpg
# Saved dataset2\photo_33.jpg
# Saved dataset2\photo_34.jpg
# Saved dataset2\photo_35.jpg
# Saved dataset2\photo_36.jpg
# Saved dataset2\photo_37.jpg
# Saved dataset2\photo_38.jpg
# Saved dataset2\photo_39.jpg
# Saved dataset2\photo_40.jpg
# Saved dataset2\photo_41.jpg
# Saved dataset2\photo_42.jpg
# Saved dataset2\photo_43.jpg
# Saved dataset2\photo_44.jpg
# Saved dataset2\photo_45.jpg
# Saved dataset2\photo_46.jpg
# Saved dataset2\photo_47.jpg
# Saved dataset2\photo_48.jpg
# Saved dataset2\photo_49.jpg
# Saved dataset2\photo_50.jpg
# Saved dataset2\photo_51.jpg
# Saved dataset2\photo_52.jpg
# Saved dataset2\photo_53.jpg
# Saved dataset2\photo_54.jpg
# Saved dataset2\photo_55.jpg
# Saved dataset2\photo_56.jpg
# Saved dataset2\photo_57.jpg
# Saved dataset2\photo_58.jpg
# Saved dataset2\photo_59.jpg
# Saved dataset2\photo_60.jpg
# Saved dataset2\photo_61.jpg
# Saved dataset2\photo_62.jpg
# Saved dataset2\photo_63.jpg
# Saved dataset2\photo_64.jpg
# Saved dataset2\photo_65.jpg
# Saved dataset2\photo_66.jpg
# Saved dataset2\photo_67.jpg
# Saved dataset2\photo_68.jpg
# Saved dataset2\photo_69.jpg
# Saved dataset2\photo_70.jpg
# Saved dataset2\photo_71.jpg
# Saved dataset2\photo_72.jpg
# Saved dataset2\photo_73.jpg
# Saved dataset2\photo_74.jpg
# Saved dataset2\photo_75.jpg
# Saved dataset2\photo_76.jpg
# Saved dataset2\photo_77.jpg
# Saved dataset2\photo_78.jpg
# Saved dataset2\photo_79.jpg
# Saved dataset2\photo_80.jpg
# Saved dataset2\photo_81.jpg
# Saved dataset2\photo_82.jpg
# Saved dataset2\photo_83.jpg
# Saved dataset2\photo_84.jpg
# Saved dataset2\photo_85.jpg
# Saved dataset2\photo_86.jpg
# Saved dataset2\photo_87.jpg
# Saved dataset2\photo_88.jpg
# Saved dataset2\photo_89.jpg
# Saved dataset2\photo_90.jpg
# Saved dataset2\photo_91.jpg
# Saved dataset2\photo_92.jpg
# Saved dataset2\photo_93.jpg
# Saved dataset2\photo_94.jpg
# Saved dataset2\photo_95.jpg
# Saved dataset2\photo_96.jpg
# Saved dataset2\photo_97.jpg
# Saved dataset2\photo_98.jpg
# Saved dataset2\photo_99.jpg
# Saved dataset2\photo_100.jpg
# Captured and saved 100 photos in 'dataset2' directory.
